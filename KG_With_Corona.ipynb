# %%
ls
# Out:
# covid_19_data.csv           time_series_covid_19_confirmed.csv
# COVID19_line_list_data.csv  time_series_covid_19_deaths.csv
# COVID19_open_line_list.csv  time_series_covid_19_recovered.csv
# KG_With_Corona.ipynb

# %% [markdown]
# #### Library imported

# %%
import pandas as pd
import glob
import os

# %%
pwd
# Out:
# '/home/tahsir/Python/Covid19Data'

# %% [markdown]
# ### Multiple data insert

# %%
# # get data file names

# path ='/home/tahsir/Python/Covid19Data'

# filenames = glob.glob(path + "/*.csv")

# dfs = []

# for filename in filenames:

#     dfs.append(pd.read_csv(filename))

# # Concatenate all data into one DataFrame

# data = pd.concat(dfs, ignore_index=False)

# %%
ls
# Out:
# covid_19_data.csv           time_series_covid_19_confirmed.csv
# COVID19_line_list_data.csv  time_series_covid_19_deaths.csv
# COVID19_open_line_list.csv  time_series_covid_19_recovered.csv
# KG_With_Corona.ipynb

# %%
# data1=pd.read_csv("covid_19_data.csv")

# %%
# data1.head()

# %%
# data1.shape

# %%
ls
# Out:
# covid_19_data.csv           time_series_covid_19_confirmed.csv
# COVID19_line_list_data.csv  time_series_covid_19_deaths.csv
# COVID19_open_line_list.csv  time_series_covid_19_recovered.csv
# KG_With_Corona.ipynb

# %%
# data2=pd.read_csv("COVID19_line_list_data.csv")

# %%
# data2.head()

# %%
# data2.shape

# %%
# ls

# %%
data3=pd.read_csv("COVID19_open_line_list.csv")

# %%
data3.head()
# Out:
#     ID age     sex                        city province country  \
# 0  1.0  30    male     Chaohu City, Hefei City    Anhui   China
# 1  2.0  47    male  Baohe District, Hefei City    Anhui   China
# 2  3.0  49    male  High-Tech Zone, Hefei City    Anhui   China
# 3  4.0  47  female  High-Tech Zone, Hefei City    Anhui   China
# 4  5.0  50  female  Feidong County, Hefei City    Anhui   China
#
#    wuhan(0)_not_wuhan(1)   latitude   longitude geo_resolution     ...       \
# 0                    1.0  31.646960  117.716600         admin3     ...
# 1                    1.0  31.778630  117.331900         admin3     ...
# 2                    1.0  31.828313  117.224844          point     ...
# 3                    1.0  31.828313  117.224844          point     ...
# 4                    1.0  32.001230  117.568100         admin3     ...
#
#   Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39 Unnamed: 40  \
# ...

# %%
data3.columns
# Out:
# Index(['ID', 'age', 'sex', 'city', 'province', 'country',
#        'wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'notes_for_discussion', 'location', 'admin3', 'admin2', 'admin1',
#        'country_new', 'admin_id', 'data_moderator_initials', 'Unnamed: 33',
#        'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
#        'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
#        'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44'],
#       dtype='object')

# %%
data=data3.drop(['Unnamed: 33',
       'Unnamed: 34', 'Unnamed: 35', 'Unnamed: 36', 'Unnamed: 37',
       'Unnamed: 38', 'Unnamed: 39', 'Unnamed: 40', 'Unnamed: 41',
       'Unnamed: 42', 'Unnamed: 43', 'Unnamed: 44'], axis=1)

# %%
data.columns
# Out:
# Index(['ID', 'age', 'sex', 'city', 'province', 'country',
#        'wuhan(0)_not_wuhan(1)', 'latitude', 'longitude', 'geo_resolution',
#        'date_onset_symptoms', 'date_admission_hospital', 'date_confirmation',
#        'symptoms', 'lives_in_Wuhan', 'travel_history_dates',
#        'travel_history_location', 'reported_market_exposure',
#        'additional_information', 'chronic_disease_binary', 'chronic_disease',
#        'source', 'sequence_available', 'outcome', 'date_death_or_discharge',
#        'notes_for_discussion', 'location', 'admin3', 'admin2', 'admin1',
#        'country_new', 'admin_id', 'data_moderator_initials'],
#       dtype='object')

# %%
data["country"].isna().sum()
# Out:
# 978

# %%
data.isna().sum()
# Out:
# ID                            953
# age                         12777
# sex                         12862
# city                         3932
# province                     1220
# country                       978
# wuhan(0)_not_wuhan(1)         956
# latitude                      979
# longitude                     979
# geo_resolution                979
# date_onset_symptoms         13380
# date_admission_hospital     13396
# date_confirmation            1037
# symptoms                    13633
# lives_in_Wuhan              13561
# travel_history_dates        13623
# travel_history_location     13368
# reported_market_exposure    14091
# additional_information      11714
# chronic_disease_binary      14108
# chronic_disease             14113
# source                       1176
# sequence_available          14125
# outcome                     13942
# date_death_or_discharge     14033
# notes_for_discussion        13939
# location                    13102
# ...

# %%
data.head()
# Out:
#     ID age     sex                        city province country  \
# 0  1.0  30    male     Chaohu City, Hefei City    Anhui   China
# 1  2.0  47    male  Baohe District, Hefei City    Anhui   China
# 2  3.0  49    male  High-Tech Zone, Hefei City    Anhui   China
# 3  4.0  47  female  High-Tech Zone, Hefei City    Anhui   China
# 4  5.0  50  female  Feidong County, Hefei City    Anhui   China
#
#    wuhan(0)_not_wuhan(1)   latitude   longitude geo_resolution  \
# 0                    1.0  31.646960  117.716600         admin3
# 1                    1.0  31.778630  117.331900         admin3
# 2                    1.0  31.828313  117.224844          point
# 3                    1.0  31.828313  117.224844          point
# 4                    1.0  32.001230  117.568100         admin3
#
#             ...            outcome date_death_or_discharge  \
# 0           ...                NaN                     NaN
# 1           ...                NaN                     NaN
# ...

# %%
data.shape
# Out:
# (14126, 33)

# %%
# data.dropna()

# %%
# data.fillna(0)

# %%
data[['ID',"age","sex"]][data.province== "Anhui"]
# Out:
#             ID  age     sex
# 0          1.0   30    male
# 1          2.0   47    male
# 2          3.0   49    male
# 3          4.0   47  female
# 4          5.0   50  female
# 5          6.0  NaN     NaN
# 6          7.0   42  female
# 7          8.0  NaN  female
# 8          9.0   59  female
# 9         10.0   30    male
# 10        11.0  NaN     NaN
# 11        12.0   39    male
# 12        13.0  NaN     NaN
# 13        14.0   38  female
# 14        15.0   45    male
# 452      459.0   40  female
# 453      460.0   51    male
# 454      461.0   37    male
# 455      462.0   55    male
# 456      463.0   32    male
# 457      464.0   24    male
# 458      465.0   39    male
# 459      466.0   25  female
# 460      467.0   56    male
# 461      468.0   44    male
# 462      469.0   50    male
# 463      470.0   42    male
# 464      471.0   43    male
# 465      472.0   22    male
# 466      473.0   43    male
# ...        ...  ...     ...
# 8432    8724.0  NaN     NaN
# ...

# %%
# data4=pd.read_csv("time_series_covid_19_confirmed.csv")

# %%
# data4.head()

# %%
# data5=pd.read_csv("time_series_covid_19_deaths.csv")

# %%
# data5.head()

# %%
# data6=pd.read_csv("time_series_covid_19_recovered.csv")

# %%
# data6.head()

# %%
# import matplotlib.pyplot as plt
# from pandas.plotting import autocorrelation_plot
# autocorrelation_plot(data6)
# plt.show()

# %%
data=[data1,data2,data3,data4,data5,data6]
for i in data:
    print(i.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-f4c8eeb2f017> in <module>()
# ----> 1 data=[data1,data2,data3,data4,data5,data6]
#       2 for i in data:
#       3     print(i.shape)
#
# NameError: name 'data1' is not defined
